# %% [markdown]
# <a href="https://colab.research.google.com/github/ambujsukhad/Stocks-Competition-Analysis/blob/main/Stock_Competiton_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BULLS EYE STOCK COMPETIOTION E-SUMMIT'22 ANALYSIS**

# %% [markdown]
# **Importing the libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the dataset**

# %%
all_trades=pd.read_csv("Atock_All_Trades.csv")
net_worth=pd.read_csv("Stock_Net_Worth.csv")
all_trades.qty=all_trades.qty.abs()
all_trades
# Out:
#                   name                        email  \
# 0            Abin John       abinjohn2003@gmail.com
# 1     Saurav Kumar jha        jhasaurav33@gmail.com
# 2           Kapil Garg       kapilgarg236@gmail.com
# 3     Saurav Kumar jha        jhasaurav33@gmail.com
# 4           Kapil Garg       kapilgarg236@gmail.com
# ...                ...                          ...
# 8759    Siddhant Patil  siddhantujjain123@gmail.com
# 8760    Siddhant Patil  siddhantujjain123@gmail.com
# 8761    Siddhant Patil  siddhantujjain123@gmail.com
# 8762    Siddhant Patil  siddhantujjain123@gmail.com
# 8763    Siddhant Patil  siddhantujjain123@gmail.com
#
#                                   company         industry   cap_type   qty  \
# 0                      Tata Power Co. Ltd        Utilities    Mid Cap     4
# 1     HDFC LIFE INSURANCE COMPANY LIMITED  Banking/Finance  Large Cap     5
# 2          Tata Consultancy Services Ltd.       Technology  Large Cap     1
# ...

# %%
net_worth
# Out:
#          id                 name                             email  \
# 0     13458        Nikhil Mishra         nikhilmishra496@gmail.com
# 1     13460         Akash Sharma        Akashsharma23oo3@gmail.com
# 2     13464  Aditya Kumar Sharma       adityakusharma112@gmail.com
# 3     13465     Siddharth Parmar     Siddharth.parmar21@iimb.ac.in
# 4     13466     Arpit maheshwary      arpitmaheshwary004@gmail.com
# ...     ...                  ...                               ...
# 1150  14058       Nishan Murarka      nishan.murarka1234@gmail.com
# 1151  14060      Pratham Patidar      patidarpratham8589@gmail.com
# 1152  14065                Sneha         sneharathore109@gmail.com
# 1153  14068        nipun agarwal        nipunagarwal9636@gmail.com
# 1154  14082        Rishabh Gupta  rishabhgupta7292572925@gmail.com
#
#             date   networth
# 0     2022-01-10  503909.00
# 1     2022-01-10  500000.00
# 2     2022-01-10  499749.80
# 3     2022-01-10  625735.50
# ...

# %% [markdown]
# **Total number of participants**

# %%
participants=pd.unique(net_worth['id'])
participants=participants.reshape(participants.size,1)
participants.shape
# Out:
# (237, 1)

# %% [markdown]
# There are 237 participants competing as participants size is (237,1)

# %% [markdown]
# **Plotting trades done on each day**

# %%
plt.figure(figsize=(8,6))
sns.countplot(all_trades['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Total trades on the basis of cap type**

# %%
sns.catplot(x='cap_type', data=all_trades, col='date',kind='count')

# %%
sns.catplot(x='cap_type', data=all_trades, col='date',kind='count',hue='action')

# %% [markdown]
# **Kernel Density Estimates for Price**

# %%
priceplot=sns.kdeplot(all_trades['price'], shade=True,)
priceplot.set(xlim=(-5000,20000))
# Out:
# [(-5000.0, 20000.0)]

# %%
priceplot=sns.kdeplot(all_trades['price'], shade=True,hue=all_trades['action'])
priceplot.set(xlim=(-5000,20000))
# Out:
# [(-5000.0, 20000.0)]

# %% [markdown]
# **Average price of trades on each day**

# %%
sns.lineplot(x='date' , y='price' , data=all_trades , hue='action')

# %%
sns.pointplot(x='date' , y='price' , data=all_trades , hue='action')

# %% [markdown]
# Average quantity of trades on each day

# %%
sns.lineplot(x='date' , y='qty' , data=all_trades , hue='action')

# %%
sns.pointplot(x='date' , y='qty' , data=all_trades , hue='action')

# %% [markdown]
# **Count of unique insdustries**

# %%
uni_indus= pd.unique(all_trades['industry'])
print('Total number of industries are : '+str(uni_indus.size))
print('Industries are following:')
for i in uni_indus:
  print(i)
# Out:
# Total number of industries are : 21
# Industries are following:
# Utilities
# Banking/Finance
# Technology
# Automotive
# Services
# Food & Beverage
# Pharmaceuticals
# Cons Durable
# Oil & Gas
# Telecom
# Chemicals
# Metals & Mining
# Retail/Real Estate
# Engineering
# Cons Non-Durable
# Cement/Construction
# Manufacturing
# Tobacco
# Media
# Conglomerates
# Miscellaneous

# %% [markdown]
# **Count of trades on different industries**

# %%
plt.figure(figsize=(35,12))
sns.countplot(x='industry', data=all_trades , )

# %%
plt.figure(figsize=(35,12))
sns.countplot(x='industry', data=all_trades , hue='action')

# %%
sns.catplot(x='industry', data=all_trades, col='date',kind='count')

# %% [markdown]
# **Number of trades on basis of price**

# %%
sns.distplot(all_trades.price, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Neglecting small number of trades

# %%
low_price = all_trades[all_trades['price']<10000]
low_price.shape
# Out:
# (8446, 10)

# %%
sns.distplot(low_price.price, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Observing high volume of trades

# %%
vlow_price=low_price[low_price.price<2000]
vlow_price.shape
# Out:
# (6268, 10)

# %%
sns.distplot(vlow_price.price, color='r' )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mlow_price=low_price[low_price.price>=2000]
mlow_price.shape
# Out:
# (2178, 10)

# %%
sns.distplot(mlow_price.price, color='g')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **No. of participants done high price trade**

# %%
high_price = all_trades[all_trades['price']>10000]
highp=pd.unique(high_price.name)
highp.size
# Out:
# 50

# %% [markdown]
# **High Price Trade Analysis**

# %%
plt.figure(figsize=(8,6))
sns.countplot(high_price['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(x='cap_type', data=high_price, col='date',kind='count',hue='action')

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='industry', data=high_price )

# %% [markdown]
# **Number of Trades on basis of quantity**

# %%
plt.figure(figsize=(18,8))
sns.distplot(all_trades.qty , kde=False , bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Individually observing small and big quantities trades

# %%
big_qty_trades=all_trades[all_trades['qty']>10000]
big_qty_trades.shape
# Out:
# (397, 10)

# %%
plt.figure(figsize=(18,8))
sns.distplot(big_qty_trades.qty, kde=False, bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
samll_qty_trades = all_trades[all_trades['qty']<=1000]
samll_qty_trades.shape
# Out:
# (7682, 10)

# %%
plt.figure(figsize=(18,8))
sns.distplot(samll_qty_trades.qty, kde=False, bins=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Observing No of participants on the basis of profit**

# %%
part_profit=net_worth[net_worth['networth']>500000]
part_profit.shape
# Out:
# (575, 5)

# %%
part_loss=net_worth[net_worth['networth']<500000]
part_loss.shape
# Out:
# (226, 5)

# %%
part_npl=net_worth[net_worth['networth']==500000]
part_npl.shape
# Out:
# (354, 5)

# %%
sns.countplot(part_profit.date)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(part_loss.date)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(part_npl.date)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pointplot(x='date', y='networth' , data =net_worth ,  )

# %% [markdown]
# **Analysis of Trades of Winners**

# %%
winners= ['Vishnu Vardhan R', 'Siddharth Parmar' ,'Priyansh Singhal']
winners_trades=pd.DataFrame()
for i in winners:
  winners_trades=pd.concat([winners_trades, all_trades[all_trades['name']==i]])
winners_trades.shape
# Out:
# (731, 10)

# %%
sns.catplot(x='name' , data=winners_trades , kind='count')

# %%
sns.catplot(x='name' , data=winners_trades , col='date' , kind='count' , col_wrap=3)

# %%
sns.catplot(x='name' , data=winners_trades , col='date' , kind='count' , hue='action')

# %%
sns.relplot(data=winners_trades , x='qty' , y='price' , hue='name')

# %%
sns.catplot(data=small_qty , y='qty' , x='name'  , hue='action' , kind='violin')

# %%
sns.catplot(data=winners_trades , y='qty' , x='name' , hue='action' , col='date' , kind='box')

# %%
small_qty=winners_trades[winners_trades.qty<10000]
sns.catplot(data=small_qty , y='qty' , x='name' , hue='action' , col='date' , kind='box')

# %%
sns.catplot(data=small_qty , y='qty' , x='name'  , col='date' , kind='violin')

# %%
sns.jointplot(x='price', y='qty' , data=small_trades , xlim=(0,4000) , ylim=(0,10000) , kind='reg')

# %%
sns.jointplot(x='price', y='qty' , data=small_trades , xlim=(0,4000) , ylim=(0,10000) , hue='name' )

# %%
sns.lineplot(y='price', x='date' , data=small_trades , hue='name')
